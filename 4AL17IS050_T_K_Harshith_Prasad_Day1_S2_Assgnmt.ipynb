# %%
n=int(input("Enter range"))
for i in range(1,n+1):
    for j in range(1,i+1):
        print("*",end="")
    print('')
# Out:
# Enter range1
# *

# %%
n=int(input("Enter range"))
for i in range(n,0,-1):
    for j in range(i,n+1):
        print(j,end=" ")
    print('')
# Out:
# Enter range5
# 5
# 4 5
# 3 4 5
# 2 3 4 5
# 1 2 3 4 5

# %%
n=int(input("Enter range"))
for i in range(n,0,-1):
    for j in range(i,0,-1):
        print(j,end="")
    print('')
# Out:
# Enter range4
# 4321
# 321
# 21
# 1

# %%
s=input("Enter the string")
c=0
for i in s:
    c=c+1
print(c)
# Out:
# Enter the stringhello
# 5

# %%
s=input("Enter the string")
c=0
d=0
for i in s:
    if i==" ":
        d=d+1
    
    c=c+1
f=c-d
print("The no. of words is {0}".format(d+1))
print("The no. of characters is {0}".format(f))
# Out:
# Enter the stringhello
# The no. of words is 1
# The no. of characters is 5

# %%
a=input("Enter string")
word=input("Enter word")
count=0
b=a.split(" ")
for i in range(0,len(b)):
    if(word==b[i]):
        count=count+1
print(count)
# Out:
# Enter stringdel
# Enter wordde
# 0

# %%
n=int(input())
for i in range(1,n+1):
  j=i;
  for k in range(1,i+1):
    print(j,end=" ")
    j=j+1
  print("\n")
# Out:
# 5
# 1
#
# 2 3
#
# 3 4 5
#
# 4 5 6 7
#
# 5 6 7 8 9

# %%
n=int(input("Enter range"))
for i in range(1,n):
    for j in range(i,n+1):
        print(j,end=" ")
    print('')
for i in range(n,0,-1):
    for j in range(i,n+1):
        print(j,end=" ")
    print('')
# Out:
# Enter range3
# 1 2 3
# 2 3
# 3
# 2 3
# 1 2 3
